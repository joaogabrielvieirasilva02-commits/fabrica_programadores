# %% [markdown]
# # NumPy na Prática — Exercícios Progressivos
#
# ## Objetivo
#
# Nesta atividade, você utilizará **NumPy** para resolver problemas inspirados em situações reais de empresas, finanças, estoque, vendas e recursos humanos.
#
# A proposta não é revisar Python básico, mas praticar principalmente:
#
# - criação e manipulação de `ndarray`;
# - operações vetorizadas;
# - indexação e slicing;
# - máscaras booleanas;
# - `np.where()` e `np.select()`;
# - funções estatísticas;
# - matrizes bidimensionais;
# - operações com `axis`;
# - broadcasting;
# - transformação de arrays;
# - análise de pequenos conjuntos de dados.
#
# > Sempre que possível, evite resolver os exercícios com `for`.
# > Procure pensar em **operações vetorizadas com NumPy**.

# %%
import numpy as np

# %% [markdown]
# ## Exercício 1 — Dissídio anual de uma equipe
#
# O departamento de Recursos Humanos possui os seguintes salários:
#
# ```python
# salarios = np.array([1850, 2300, 2750, 3200, 4100, 5250, 6800, 8400])
# ```
#
# A convenção coletiva determinou um **dissídio de 5,7%**.
#
# Utilizando NumPy:
#
# 1. calcule o valor do reajuste de cada funcionário;
# 2. crie um array com os novos salários;
# 3. calcule o custo total da folha antes do reajuste;
# 4. calcule o custo total da folha depois do reajuste;
# 5. descubra quanto a empresa gastará a mais por mês.
#
# **Restrição:** não utilize `for`.

# %%
salarios = np.array([1850, 2300, 2750, 3200, 4100, 5250, 6800, 8400])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 2 — Reajustes diferentes por faixa salarial
#
# A empresa decidiu aplicar reajustes diferentes:
#
# - salários abaixo de R$ 3.000 → **7%**
# - salários entre R$ 3.000 e R$ 5.000 → **5%**
# - salários acima de R$ 5.000 → **3%**
#
# Utilize o array do exercício anterior.
#
# Crie um novo array contendo o percentual de reajuste correspondente a cada funcionário e calcule os novos salários.
#
# ### Desafio
# Resolva utilizando `np.select()`.

# %%
# Utilize o array salarios do exercício anterior

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 3 — Filtrando salários acima da média
#
# Com base no array `salarios`:
#
# 1. calcule a média salarial;
# 2. crie uma máscara booleana identificando quem recebe acima da média;
# 3. exiba somente os salários acima da média;
# 4. conte quantos funcionários estão acima da média;
# 5. calcule qual porcentagem da equipe está acima da média.
#
# Use máscaras booleanas do NumPy.

# %%
# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 4 — Análise de vendas mensais
#
# Uma loja registrou as seguintes vendas nos últimos 12 meses:
#
# ```python
# vendas = np.array([
#     32500, 34800, 30100, 38900,
#     41200, 43700, 40100, 45500,
#     47800, 50200, 49100, 53000
# ])
# ```
#
# Calcule:
#
# 1. total vendido no ano;
# 2. média mensal;
# 3. maior venda mensal;
# 4. menor venda mensal;
# 5. posição do melhor mês usando `np.argmax()`;
# 6. quantos meses ficaram acima da média.
#
# ### Desafio
# Calcule a variação percentual entre o primeiro e o último mês.

# %%
vendas = np.array([
    32500, 34800, 30100, 38900,
    41200, 43700, 40100, 45500,
    47800, 50200, 49100, 53000
])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 5 — Meta de vendas
#
# Utilize o array `vendas`.
#
# A meta mensal da loja é de **R$ 42.000**.
#
# Crie:
#
# 1. uma máscara indicando quais meses atingiram a meta;
# 2. um array contendo `"Meta atingida"` ou `"Abaixo da meta"`;
# 3. a quantidade de meses que atingiram a meta;
# 4. o percentual de meses em que a meta foi atingida;
# 5. o total vendido apenas nos meses que atingiram a meta.
#
# Use `np.where()` em pelo menos uma etapa.

# %%
meta = 42000

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 6 — Controle de estoque
#
# Uma loja possui os seguintes estoques atuais:
#
# ```python
# estoque = np.array([12, 45, 8, 30, 4, 67, 21, 9])
# estoque_minimo = np.array([10, 20, 10, 25, 8, 40, 20, 15])
# ```
#
# Crie uma análise que:
#
# 1. identifique os produtos abaixo do estoque mínimo;
# 2. mostre quantas unidades faltam para cada produto chegar ao mínimo;
# 3. substitua por `0` os valores dos produtos que já possuem estoque suficiente;
# 4. calcule quantas unidades precisam ser compradas no total.
#
# ### Desafio
# Calcule a quantidade necessária para deixar cada produto **20% acima do estoque mínimo**.

# %%
estoque = np.array([12, 45, 8, 30, 4, 67, 21, 9])
estoque_minimo = np.array([10, 20, 10, 25, 8, 40, 20, 15])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 7 — Notas de uma turma
#
# As notas finais de uma turma estão armazenadas em:
#
# ```python
# notas = np.array([8.5, 6.0, 4.5, 7.2, 9.1, 5.8, 6.9, 3.7, 8.0, 7.5])
# ```
#
# Classifique cada aluno como:
#
# - nota >= 7 → **Aprovado**
# - nota >= 5 e < 7 → **Recuperação**
# - nota < 5 → **Reprovado**
#
# Depois calcule:
#
# 1. média da turma;
# 2. mediana;
# 3. desvio padrão;
# 4. quantidade de aprovados;
# 5. quantidade em recuperação;
# 6. quantidade de reprovados.
#
# ### Desafio
# Use `np.select()` para criar as classificações.

# %%
notas = np.array([8.5, 6.0, 4.5, 7.2, 9.1, 5.8, 6.9, 3.7, 8.0, 7.5])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 8 — Horas extras
#
# Uma equipe possui os seguintes salários mensais:
#
# ```python
# salarios = np.array([2200, 2800, 3500, 4100, 5200])
# ```
#
# E realizou as seguintes horas extras:
#
# ```python
# horas_extras = np.array([5, 12, 8, 20, 3])
# ```
#
# Considere:
#
# - jornada mensal: 220 horas;
# - adicional de hora extra: 50%.
#
# Calcule de forma vetorizada:
#
# 1. valor da hora normal;
# 2. valor da hora extra;
# 3. total de horas extras recebido por funcionário;
# 4. salário total do mês;
# 5. custo total das horas extras para a empresa.

# %%
salarios = np.array([2200, 2800, 3500, 4100, 5200])
horas_extras = np.array([5, 12, 8, 20, 3])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 9 — Matriz de vendas por vendedor
#
# A matriz abaixo representa as vendas de 4 vendedores durante 5 semanas:
#
# ```python
# vendas_equipe = np.array([
#     [4200, 5100, 4800, 5300, 4900],
#     [3900, 4200, 4500, 4100, 4600],
#     [6100, 5900, 6400, 6200, 6800],
#     [4700, 5200, 5000, 5500, 5700]
# ])
# ```
#
# Cada **linha** representa um vendedor e cada **coluna** representa uma semana.
#
# Calcule:
#
# 1. total vendido por vendedor;
# 2. média vendida por vendedor;
# 3. total vendido por semana;
# 4. vendedor com maior faturamento total;
# 5. semana com maior faturamento da equipe.
#
# Use corretamente o parâmetro `axis`.

# %%
vendas_equipe = np.array([
    [4200, 5100, 4800, 5300, 4900],
    [3900, 4200, 4500, 4100, 4600],
    [6100, 5900, 6400, 6200, 6800],
    [4700, 5200, 5000, 5500, 5700]
])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 10 — Comissão por vendedor
#
# Utilize a matriz `vendas_equipe`.
#
# A empresa paga **4% de comissão sobre o total vendido** por cada vendedor.
#
# Calcule:
#
# 1. faturamento total de cada vendedor;
# 2. comissão de cada vendedor;
# 3. total pago em comissões;
# 4. maior comissão;
# 5. diferença entre a maior e a menor comissão.
#
# ### Desafio
# Funcionários que venderam mais de R$ 27.000 recebem comissão de **5%** em vez de 4%.
#
# Calcule as comissões novamente sem utilizar loops.

# %%
# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 11 — Broadcasting: reajuste por departamento
#
# Uma empresa possui três departamentos. A matriz representa os salários dos funcionários:
#
# ```python
# salarios_departamentos = np.array([
#     [2500, 3100, 4200, 3800],
#     [2800, 3500, 4600, 5200],
#     [1900, 2300, 2700, 3000]
# ])
# ```
#
# Cada linha representa um departamento.
#
# Os reajustes serão:
#
# ```python
# reajustes = np.array([1.05, 1.07, 1.04])
# ```
#
# Ou seja:
#
# - departamento 1 → 5%
# - departamento 2 → 7%
# - departamento 3 → 4%
#
# Utilize **broadcasting** para aplicar o reajuste correto a todos os funcionários.
#
# Depois calcule:
#
# 1. nova matriz salarial;
# 2. custo da folha por departamento antes do reajuste;
# 3. custo depois do reajuste;
# 4. aumento de custo por departamento.

# %%
salarios_departamentos = np.array([
    [2500, 3100, 4200, 3800],
    [2800, 3500, 4600, 5200],
    [1900, 2300, 2700, 3000]
])

reajustes = np.array([1.05, 1.07, 1.04])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 12 — Análise de preços e inflação
#
# Os preços de cinco produtos foram registrados em janeiro e novamente em dezembro.
#
# ```python
# janeiro = np.array([5.50, 12.90, 8.75, 22.00, 4.80])
# dezembro = np.array([6.20, 14.50, 9.10, 25.90, 5.30])
# ```
#
# Calcule:
#
# 1. aumento absoluto de cada produto;
# 2. aumento percentual de cada produto;
# 3. produto com maior aumento percentual;
# 4. aumento percentual médio;
# 5. quais produtos aumentaram mais de 10%.
#
# ### Desafio
# Crie um array com os índices dos produtos que tiveram aumento acima da média.

# %%
janeiro = np.array([5.50, 12.90, 8.75, 22.00, 4.80])
dezembro = np.array([6.20, 14.50, 9.10, 25.90, 5.30])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 13 — Transformando dados com reshape
#
# Um sistema exportou as vendas de 24 períodos em um único array:
#
# ```python
# dados = np.array([
#     120, 135, 142, 150, 160, 155,
#     170, 180, 175, 190, 205, 210,
#     215, 225, 230, 245, 250, 260,
#     270, 265, 280, 295, 310, 325
# ])
# ```
#
# Considere que esses valores representam **4 vendedores**, com **6 registros para cada vendedor**.
#
# 1. transforme o array em uma matriz 4 × 6 usando `reshape`;
# 2. calcule o total por vendedor;
# 3. calcule a média por período;
# 4. transponha a matriz;
# 5. explique, em uma célula Markdown ou comentário, o que mudou após a transposição.
#
# ### Desafio
# Transforme novamente a matriz em um array unidimensional.

# %%
dados = np.array([
    120, 135, 142, 150, 160, 155,
    170, 180, 175, 190, 205, 210,
    215, 225, 230, 245, 250, 260,
    270, 265, 280, 295, 310, 325
])

# Desenvolva sua solução abaixo

# %% [markdown]
# ## Exercício 14 — Detectando valores fora do padrão
#
# Uma indústria registrou o tempo, em minutos, necessário para produzir uma peça:
#
# ```python
# tempos = np.array([
#     12.1, 11.8, 12.4, 12.0, 11.9,
#     12.3, 30.5, 12.2, 11.7, 12.1,
#     11.8, 12.0
# ])
# ```
#
# Um valor pode ser considerado suspeito quando estiver a mais de **2 desvios padrão da média**.
#
# Calcule:
#
# 1. média;
# 2. desvio padrão;
# 3. limite inferior;
# 4. limite superior;
# 5. valores que estão fora desses limites.
#
# ### Desafio
# Crie um novo array removendo os valores considerados fora do padrão.

# %%
tempos = np.array([
    12.1, 11.8, 12.4, 12.0, 11.9,
    12.3, 30.5, 12.2, 11.7, 12.1,
    11.8, 12.0
])

# Desenvolva sua solução abaixo

# %% [markdown]
# # Exercício 15 — Desafio: análise de folha de pagamento com NumPy
#
# Uma empresa exportou os dados de seis funcionários.
#
# ```python
# # Colunas:
# # 0 = salário base
# # 1 = horas extras
# # 2 = nota de desempenho
# # 3 = anos de empresa
#
# funcionarios = np.array([
#     [2500,  8,  85,  2],
#     [3200, 12,  92,  5],
#     [4100,  5,  78,  8],
#     [2800, 20,  95,  3],
#     [5300,  3,  88, 12],
#     [3700, 10,  70,  6]
# ], dtype=float)
# ```
#
# ## Regras
#
# ### Dissídio
#
# Todos os funcionários recebem **5% de reajuste**.
#
# ### Horas extras
#
# - jornada mensal: 220 horas;
# - adicional: 50%.
#
# ### Bônus por desempenho
#
# - nota >= 90 → 8% do salário reajustado;
# - nota entre 80 e 89 → 4%;
# - abaixo de 80 → sem bônus.
#
# ## Sua tarefa
#
# Utilizando NumPy, calcule:
#
# 1. salários base;
# 2. salários após o dissídio;
# 3. valores das horas extras;
# 4. bônus por desempenho;
# 5. salário final de cada funcionário;
# 6. custo total da folha;
# 7. média salarial final;
# 8. maior salário final;
# 9. menor salário final;
# 10. quantidade de funcionários que receberam bônus.
#
# ### Desafio adicional
#
# Crie uma matriz final com as seguintes colunas:
#
# ```text
# salário base | reajustado | horas extras | bônus | salário final
# ```
#
# Depois:
#
# - ordene os funcionários pelo salário final;
# - identifique os funcionários cujo salário final está acima da média;
# - calcule quanto os bônus representam, em percentual, do custo total da folha.
#
# > Tente realizar toda a análise sem utilizar loops.

# %%
# Colunas:
# 0 = salário base
# 1 = horas extras
# 2 = nota de desempenho
# 3 = anos de empresa

funcionarios = np.array([
    [2500,  8,  85,  2],
    [3200, 12,  92,  5],
    [4100,  5,  78,  8],
    [2800, 20,  95,  3],
    [5300,  3,  88, 12],
    [3700, 10,  70,  6]
], dtype=float)

# Desenvolva sua solução abaixo

# %% [markdown]
# ---
#
# # Checklist de NumPy
#
# Antes de entregar, verifique se você utilizou adequadamente:
#
# - `np.array()`;
# - operações vetorizadas;
# - máscaras booleanas;
# - indexação de arrays;
# - `np.where()` ou `np.select()`;
# - `sum`, `mean`, `min`, `max`, `std`;
# - `argmin` e `argmax`;
# - matrizes 2D;
# - `axis`;
# - broadcasting;
# - `reshape`;
# - transposição;
# - filtragem de dados.
#
# ## Regra geral
#
# Se uma operação puder ser realizada diretamente sobre todo o array, prefira essa abordagem em vez de percorrer os elementos manualmente com `for`.
